# %% [markdown]
# # Statistische Analyse von YouTube Videos

# %% [markdown]
# Importieren aller benötigter Bibliotheken

# %%
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
import matplotlib.pyplot as plt
import wordcloud as wc
import nltk as nltk
import re as re

from nltk.sentiment import SentimentIntensityAnalyzer

# %% [markdown]
# Einlesen alle Dateien, inklusive CSV und JSON

# %%
de_videos =pd.read_csv('input/DEvideos.csv')
de_kategorien = pd.read_json('input/DE_category_id.json')
de_kategorien = {int(category['id']): category['snippet']['title'] for category in de_kategorien['items']}
us_videos =pd.read_csv('input/USvideos.csv')
us_kategorien = pd.read_json('input/US_category_id.json')
us_kategorien = {int(category['id']): category['snippet']['title'] for category in us_kategorien['items']}
ka_videos =pd.read_csv('input/CAvideos.csv')
ka_kategorien = pd.read_json('input/CA_category_id.json')
ka_kategorien = {int(category['id']): category['snippet']['title'] for category in ka_kategorien['items']}
gb_videos =pd.read_csv('input/GBvideos.csv')
gb_kategorien = pd.read_json('input/GB_category_id.json')
gb_kategorien = {int(category['id']): category['snippet']['title'] for category in gb_kategorien['items']}

# %% [markdown]
# Zusammenfügen aller Kategorien zu einem Dictionary

# %%
alle_kategorien = de_kategorien
for (key,value) in us_kategorien.items():
    if key not in alle_kategorien:
        alle_kategorien[key] = value
for (key,value) in ka_kategorien.items():
    if key not in alle_kategorien:
        alle_kategorien[key] = value
for (key,value) in gb_kategorien.items():
    if key not in alle_kategorien:
        alle_kategorien[key] = value

# %% [markdown]
# ## Datenbereinigung und Preprocessing

# %% [markdown]
# Anpassen der Datumsangaben

# %%
de_videos['trending_date']=pd.to_datetime(de_videos['trending_date'], format='%y.%d.%m').dt.date
us_videos['trending_date']=pd.to_datetime(us_videos['trending_date'], format='%y.%d.%m').dt.date
ka_videos['trending_date']=pd.to_datetime(ka_videos['trending_date'], format='%y.%d.%m').dt.date
gb_videos['trending_date']=pd.to_datetime(gb_videos['trending_date'], format='%y.%d.%m').dt.date

# %%
de_videos['publish_date']=pd.to_datetime(de_videos['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.date
de_videos.drop('publish_time',axis=1,inplace=True)
us_videos['publish_date']=pd.to_datetime(us_videos['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.date
us_videos.drop('publish_time',axis=1,inplace=True)
ka_videos['publish_date']=pd.to_datetime(ka_videos['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.date
ka_videos.drop('publish_time',axis=1,inplace=True)
gb_videos['publish_date']=pd.to_datetime(gb_videos['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ').dt.date
gb_videos.drop('publish_time',axis=1,inplace=True)

# %% [markdown]
# Einträge mit null-Value bei Description mit einem Leerstring füllen

# %%
de_videos['description'] = de_videos['description'].fillna('')
us_videos['description'] = us_videos['description'].fillna('')
ka_videos['description'] = ka_videos['description'].fillna('')
gb_videos['description'] = gb_videos['description'].fillna('')

# %% [markdown]
# Füllen der Kategorie-ID's mit den entsprechenden Strings

# %%
de_videos.insert(4,'category', de_videos['category_id'].map(alle_kategorien))
de_videos.drop('category_id',axis=1,inplace=True)
us_videos.insert(4,'category', us_videos['category_id'].map(alle_kategorien))
us_videos.drop('category_id',axis=1,inplace=True)
ka_videos.insert(4,'category', ka_videos['category_id'].map(alle_kategorien))
ka_videos.drop('category_id',axis=1,inplace=True)
gb_videos.insert(4,'category', gb_videos['category_id'].map(alle_kategorien))
gb_videos.drop('category_id',axis=1,inplace=True)

# %% [markdown]
# Zusammenfassen aller Videodateien zu einer großen Datei

# %%
de_videos['country']='Deutschland'
us_videos['country']='USA'
ka_videos['country']='Kanada'
gb_videos['country']='Großbritannien'
frames=[de_videos,us_videos,ka_videos,gb_videos]
alle_videos=pd.concat(frames)
frames=[us_videos,ka_videos,gb_videos]
eng_videos=pd.concat(frames)

# %% [markdown]
# ## Analyse

# %% [markdown]
# ### Standardabfragen zu Views/ Likes/ Dislikes und Comments

# %%
alle_dateien=[de_videos,us_videos,ka_videos,gb_videos]
for verarbeitungs_daten in alle_dateien:

    fig=plt.figure()
    fig.suptitle(verarbeitungs_daten['country'][0],y=0.95,fontsize=15)
    fig.subplots_adjust(hspace=0.25,wspace=0.15)
    fig.set_size_inches(15.5, 10.5)
    
    ax=fig.add_subplot(2,2,1)
    column='views'
    anzeige_daten = verarbeitungs_daten[verarbeitungs_daten[column]<
                    (verarbeitungs_daten[column].quantile(0.75)+(verarbeitungs_daten[column].quantile(0.5)))][column]
    sns.distplot(anzeige_daten,kde=False,ax=ax).set_title('Anzahl Views')
    ax.set_xlabel('Views')
    ax.set_ylabel('Anzahl')

    ax=fig.add_subplot(2,2,2)
    column='comment_count'
    anzeige_daten = verarbeitungs_daten[verarbeitungs_daten[column]<
                    (verarbeitungs_daten[column].quantile(0.75)+(verarbeitungs_daten[column].quantile(0.5)))][column]
    sns.distplot(anzeige_daten,kde=False,ax=ax).set_title('Anzahl Kommentare')
    ax.set_xlabel('Kommentare')
    ax.set_ylabel('Anzahl')
    
    ax=fig.add_subplot(2,2,3)
    column='likes'
    anzeige_daten = verarbeitungs_daten[verarbeitungs_daten[column]<
                    (verarbeitungs_daten[column].quantile(0.75)+(verarbeitungs_daten[column].quantile(0.5)))][column]
    sns.distplot(anzeige_daten,kde=False,ax=ax).set_title('Anzahl Likes')
    ax.set_xlabel('Likes')
    ax.set_ylabel('Anzahl')
    
    ax=fig.add_subplot(2,2,4)
    column='dislikes'
    anzeige_daten = verarbeitungs_daten[verarbeitungs_daten[column]<
                    (verarbeitungs_daten[column].quantile(0.75)+(verarbeitungs_daten[column].quantile(0.5)))][column]
    sns.distplot(anzeige_daten,kde=False,ax=ax).set_title('Anzahl Dislikes')
    ax.set_xlabel('Dislikes')
    ax.set_ylabel('Anzahl')

# %%
corr = alle_videos[['views','comment_count','likes','dislikes']].corr()
f,ax1 = plt.subplots()    
sns.heatmap(corr,cmap='Blues',vmin=0.6,annot=True,annot_kws={"size":10},ax=ax1)
ax1.set_title("Korrelation zwischen Integer-Werten",pad=20)
ax1.set_ylim(4,-0.1)
# Out:
# (4, -0.1)

# %%
value_counts=alle_videos['ratings_disabled'].value_counts().to_dict()

values = [value_counts[False], value_counts[True]]
labels= ['Nein - 99.14%', 'Ja      -   0.86%']
explode = (0, 0.5)
plt.pie(values,labels=values,explode=explode, counterclock=False, shadow=False)
plt.title('Bewertung deaktiviert')
plt.legend(labels,loc=3)
plt.show()

value_counts=alle_videos['comments_disabled'].value_counts().to_dict()

values = [value_counts[False], value_counts[True]]
labels= ['Nein - 98.18%', 'Ja      -   1.82%']
explode = (0, 0.5)
plt.pie(values,labels=values,explode=explode,counterclock=False, shadow=False)
plt.title('Kommentare deaktiviert')
plt.legend(labels,loc=3)
plt.show()

alle_videos['comments_and_rating_disabled']= (alle_videos['ratings_disabled'] & alle_videos['comments_disabled'])
value_counts=alle_videos['comments_and_rating_disabled'].value_counts().to_dict()

values = [value_counts[False], value_counts[True]]
labels= ['Nein - 99.61%', 'Ja      -   0.39%']
explode = (0, 0.5)
plt.pie(values,labels=values,explode=explode,counterclock=False, shadow=False)
plt.title('Bewertung und Kommentare deaktiviert')
plt.legend(labels,loc=3)
plt.show()

# %% [markdown]
# ### Abfragen zum Titel

# %%
#Länge des Titels
f,ax =plt.subplots()
alle_videos['titellaenge'] = alle_videos['title'].apply(lambda x:len(x))
sns.distplot(alle_videos['titellaenge'],kde=False,ax=ax).set_title('Titellänge')
ax.set_xlabel('Titellänge - Alle Videos')
ax.set_ylabel('Anzahl')
print('Druchschnittslänge komplett: '+str(np.mean(alle_videos['titellaenge'])))

f,ax =plt.subplots()
eng_videos['titellaenge'] = eng_videos['title'].apply(lambda x:len(x))
sns.distplot(eng_videos['titellaenge'],kde=False,ax=ax).set_title('Titellänge')
ax.set_xlabel('Titellänge - international')
ax.set_ylabel('Anzahl')
print('Druchschnittslänge international: '+str(np.mean(eng_videos['titellaenge'])))

f,ax =plt.subplots()
de_videos['titellaenge'] = de_videos['title'].apply(lambda x:len(x))
sns.distplot(de_videos['titellaenge'],kde=False,ax=ax).set_title('Titellänge')
ax.set_xlabel('Titellänge - national')
ax.set_ylabel('Anzahl')
print('Druchschnittslänge national: '+str(np.mean(de_videos['titellaenge'])))
# Out:
# Druchschnittslänge komplett: 51.836433849467156
# Druchschnittslänge international: 50.62855084226393
# Druchschnittslänge national: 55.40761508325171

# %%
#Länge des Titels in Bezug auf Views
f,ax=plt.subplots()
ax= sns.scatterplot(x='titellaenge',y='views',data=alle_videos,linewidths=0.5, edgecolors="#000000")
ax.set_xlabel('Titellänge')
ax.set_ylabel('Views')

alle_videos[['views','titellaenge']].corr()
# Out:
#                 views  titellaenge
# views        1.000000    -0.050854
# titellaenge -0.050854     1.000000

# %%
#Videos in Caps geschrieben
alle_videos['titel_in_caps'] = alle_videos['title'].apply(lambda x:x.isupper())


plt.show(print('Druchschnittsviews in Caps: '+
               str(np.mean(alle_videos[alle_videos['titel_in_caps'] ==True]['views']))))
plt.show(print('Druchschnittsviews nicht in Caps: '
               +str(np.mean(alle_videos[alle_videos['titel_in_caps'] ==False]['views']))))

value_counts=alle_videos['titel_in_caps'].value_counts().to_dict()

values = [value_counts[False], value_counts[True]]
labels= ['Nein - 93.93%', 'Ja      -   6.07%']
explode = (0, 0.5)
plt.pie(values,labels=values,explode=explode,counterclock=False, shadow=False)
plt.title('Titel wurde in Großbuchstaben geschrieben')
plt.legend(labels,loc=3)
# Out:
# Druchschnittsviews in Caps: 1509936.148189699
# Druchschnittsviews nicht in Caps: 2526489.7099571093

# %% [markdown]
# ### Korrelation von Trend Videos zwischen den einzelnen Ländern

# %%
#Funktion wird nicht erneut ausgeführt, da Durchlauf sehr lange dauert
#Ergebnis wurde in CSV Datei abgelegt, sodass diese erneut geladen werden kann

#corr_list = pd.DataFrame(alle_videos['video_id'].unique(), columns=['video_id'])
#for country_code in alle_videos['country'].unique():
#    corr_list[country_code] = 0
#corr_list['total']=0
#corr_list=corr_list.set_index('video_id')
#countries=['Deutschland','USA','Kanada','Großbritannien']
#for index in corr_list.index:
#    total=0
#    mitid= alle_videos[alle_videos['video_id']==index]
#    for country in countries:
#        size=mitid[mitid['country']==country].index.size
#        total+=size
#        corr_list.loc[[index],[country]] = size
#    corr_list.loc[[index],['total']]= total

corr_list=pd.read_csv('input/videoCountCountry.csv');
corr_list=corr_list.set_index('video_id')
corr = corr_list[['Deutschland','USA','Kanada','Großbritannien']].corr()
f,ax1=plt.subplots()
sns.heatmap(corr,cmap='Blues',vmax=0.3,annot=True,annot_kws={"size":12},ax=ax1)
plt.yticks(rotation=0)
ax1.set_title("Korrelation der Videos zwischen Ländern",pad=20)
ax1.set_ylim(4,0)
# Out:
# (4, 0)

# %% [markdown]
# ### Abfragen zu den Kategorien

# %%
cat_plot = de_videos['category'].value_counts().reset_index()
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=cat_plot['category'],y=cat_plot['index'],data=cat_plot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Kategorien in Deutschland')
ax.set_xlabel('Anzahl')
ax.set_ylabel('Kategorie')

cat_plot = us_videos['category'].value_counts().reset_index()
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=cat_plot['category'],y=cat_plot['index'],data=cat_plot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Kategorien in USA')
ax.set_xlabel('Anzahl')
ax.set_ylabel('Kategorie')

cat_plot = ka_videos['category'].value_counts().reset_index()
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=cat_plot['category'],y=cat_plot['index'],data=cat_plot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Kategorien in Kanada')
ax.set_xlabel('Anzahl')
ax.set_ylabel('Kategorie')

cat_plot = gb_videos['category'].value_counts().reset_index()
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=cat_plot['category'],y=cat_plot['index'],data=cat_plot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Kategorien in Großbritannien')
ax.set_xlabel('Anzahl')
ax.set_ylabel('Kategorie')
# Out:
# Text(0, 0.5, 'Kategorie')

# %%
catplot = alle_videos.groupby('category')['likes'].agg('sum') / alle_videos.groupby('category')['dislikes'].agg('sum')
catplot = catplot.sort_values(ascending=False).reset_index()
catplot.columns = ['category','rate']
catplot.drop([17],axis=0,inplace=True)
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=catplot['rate'],y=catplot['category'],data=catplot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Likes/ Dislikes Verhältnis')
ax.set_xlabel('Verhältnis')
ax.set_ylabel('Kategorie')

catplot = alle_videos.groupby('category')['comment_count'].agg('sum') / alle_videos.groupby('category')['views'].agg('sum')
catplot = catplot.sort_values(ascending=False).reset_index()
catplot.columns = ['category','rate']
catplot.drop([17],axis=0,inplace=True)
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=catplot['rate'],y=catplot['category'],data=catplot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Comments/ Views Verhältnis')
ax.set_xlabel('Verhältnis')
ax.set_ylabel('Kategorie')

catplot = alle_videos.groupby('category')['likes'].agg('sum') / alle_videos.groupby('category')['views'].agg('sum')
catplot = catplot.sort_values(ascending=False).reset_index()
catplot.columns = ['category','rate']
catplot.drop([17],axis=0,inplace=True)
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=catplot['rate'],y=catplot['category'],data=catplot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Likes/ Views Verhältnis')
ax.set_xlabel('Verhältnis')
ax.set_ylabel('Kategorie')

catplot = alle_videos.groupby('category')['dislikes'].agg('sum') / alle_videos.groupby('category')['views'].agg('sum')
catplot = catplot.sort_values(ascending=False).reset_index()
catplot.columns = ['category','rate']
catplot.drop([17],axis=0,inplace=True)
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=catplot['rate'],y=catplot['category'],data=catplot,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Dislikes/ Views Verhältnis')
ax.set_xlabel('Verhältnis')
ax.set_ylabel('Kategorie')
# Out:
# Text(0, 0.5, 'Kategorie')

# %% [markdown]
# ### Abfragen zum Veröffentlichungsdatum und zum Trend Datum

# %%
dauerZumTrend = {}
erste_eintraege = alle_videos.reset_index().drop_duplicates('video_id',keep='first').set_index('video_id')
erste_differenzen = (erste_eintraege['trending_date']).astype('datetime64[ns]')-erste_eintraege['publish_date'].astype('datetime64[ns]')

erste_differenzen = erste_differenzen.reset_index()
erste_differenzen.columns = ['video_id','dauerZumTrend']

for i, row in erste_differenzen.iterrows():
    dauerZumTrend[row['video_id']] = row['dauerZumTrend'].days

letzte_differenzen = alle_videos['trending_date'].astype('datetime64[ns]')-alle_videos['publish_date'].astype('datetime64[ns]')
letzte_differenzen = letzte_differenzen.reset_index()
letzte_differenzen.columns = ['video_id','dauerZumTrendLetzer']
alle_videos=alle_videos.reset_index()
alle_videos.insert(4,'dauerZumTrendLetzer', letzte_differenzen['dauerZumTrendLetzer'].astype('timedelta64[D]').astype(int))
alle_videos.insert(4, 'dauerZumTrend', alle_videos['video_id'].map(dauerZumTrend))
alle_videos.insert(4, 'trenddauer', 0)
alle_videos['trenddauer'] = (alle_videos['dauerZumTrendLetzer']-alle_videos['dauerZumTrend'])+1
alle_videos['trenddauer'] = alle_videos['trenddauer'].apply(lambda x: abs(x))

# %%
alle_videos['dauerZumTrend'] = alle_videos['dauerZumTrend'].clip(upper=365)
cat_trend_duration= alle_videos.groupby(['trenddauer','dauerZumTrend']).count()['video_id'].unstack().clip(upper=300)
plt.figure(figsize=(15,10))
ax = sns.heatmap(cat_trend_duration,cmap='Blues')
ax.invert_yaxis()
ax.set_xlabel('Zeitdauer bis zum Trend')
ax.set_ylabel('Trenddauer')
plt.title("Korrelation zwischen Zeitdauer bis zum Trend und Trenddauer",pad=20)
# Out:
# Text(0.5, 1, 'Korrelation zwischen Zeitdauer bis zum Trend und Trenddauer')

# %%
catZuTrenddauer=alle_videos.groupby(['category','trenddauer']).count()['index'].unstack()
plt.figure(figsize=(15,10))
ax = sns.heatmap(catZuTrenddauer,cmap='Blues',vmax=500)
ax.invert_yaxis()
ax.set_xlabel('Trenddauer')
ax.set_ylabel('Kategorien')
plt.title("Kategorien zu Trenddauer",pad=20)
# Out:
# Text(0.5, 1, 'Kategorien zu Trenddauer')

# %%
alle_videos["tagDerVeroeffentlichung"] = alle_videos["publish_date"].apply(
    lambda x: x.strftime('%a'))
tage=alle_videos['tagDerVeroeffentlichung'].value_counts().reset_index()
fig = plt.figure()
ax= fig.add_subplot()
ax= sns.barplot(x=tage['tagDerVeroeffentlichung'],y=tage['index'],data=tage,ax=ax)
fig.set_size_inches(7, 5)
ax.set_title('Tage der Veröffentlichung')
ax.set_xlabel('Anzahl')
ax.set_ylabel('Tag der Veröffentlichung')
# Out:
# Text(0, 0.5, 'Tag der Veröffentlichung')

# %% [markdown]
# ### Abfragen zu den Tags

# %%
MAX_N = 1000

#remove all the stopwords from the text
en_stopwords = list(nltk.corpus.stopwords.words('english'))
de_stopwords = list(nltk.corpus.stopwords.words('german'))   
en_stopwords.extend(de_stopwords)
polarities = list()
cat_list=alle_videos['category'].unique()
cat_list=cat_list[cat_list!='Trailers']

#for cate in cat_list:
#    print(cate)
#    tw= alle_videos[alle_videos['category']==cate]['tags'].str.lower().str.cat(sep=' ')
#    tw = re.sub('[^A-Za-z]+', ' ', tw)
#    tw=nltk.word_tokenize(tw)
#    tw=[w for w in tw if not w in en_stopwords]
#    tw= [word for word in tw if len(word) > 2]
#    tw=nltk.FreqDist(tw)
#    tw=pd.DataFrame(tw.most_common(MAX_N),
#                        columns=['Word', 'Frequency'])
#    compound = .0
#   for word in tw['Word'].head(MAX_N):
#       compound += SentimentIntensityAnalyzer().polarity_scores(word)['compound']
#    polarities.append(compound)
#    print(compound)
    
#polarities = pd.DataFrame(polarities)
#polarities.to_csv('input/polaritaeten.csv',index=False)
polarities = pd.read_csv('input/polaritaeten.csv')
category_list = pd.DataFrame(cat_list)
cat_tags_sentiment = pd.concat([category_list,polarities],axis=1)
cat_tags_sentiment.columns = ['category','polarity']
cat_tags_sentiment=cat_tags_sentiment.sort_values('polarity').reset_index()


plt.figure(figsize=(10,10))
sns.set(style="dark",context="notebook")
ax = sns.barplot(x=cat_tags_sentiment['polarity'],y=cat_tags_sentiment['category'], data=cat_tags_sentiment)
plt.xlabel("Sentiment")
plt.ylabel("Kategorien")
plt.title("Sentiment der Kategorien",pad=20)
# Out:
# Text(0.5, 1.0, 'Sentiment der Kategorien')

# %%
tags = alle_videos[alle_videos['category']=='Science & Technology']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Science & Technology gesamt',fontsize=20)
tags = de_videos[de_videos['category']=='Science & Technology']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Science & Technology deutsch',fontsize=20)

tags = alle_videos[alle_videos['category']=='Education']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Education gesamt',fontsize=20)
tags = de_videos[de_videos['category']=='Education']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Education deutsch',fontsize=20)

tags = alle_videos[alle_videos['category']=='Howto & Style']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Howto & Style gesamt',fontsize=20)
tags = de_videos[de_videos['category']=='Howto & Style']['tags'].str.lower().str.cat(sep=' ')
tags = re.sub('[^A-Za-z]+', ' ', tags)
tags = nltk.word_tokenize(tags)
tags = [w for w in tags if not w in en_stopwords]
tags = [word for word in tags if len(word) > 2]
tags = [word for word in tags if not word.isdigit()]
plt.figure(figsize = (15,12))
cloud = wc.WordCloud(background_color = 'white', max_words = 100,  max_font_size = 60)
cloud.generate(' '.join(tags))
plt.imshow(cloud)
plt.axis('off')
plt.title('Howto & Style deutsch',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Howto & Style deutsch')
